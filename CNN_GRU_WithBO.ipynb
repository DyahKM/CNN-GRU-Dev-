# %% [markdown]
# # **1. Install and Import Libraries**
# Dalam penggunaan Google Collab, sebelum menggunakan fitur-fitur yang tersedia dalam library yang sudah dijelaskan sebelumnya (NumPy, Matplotlib, dsb.), library yang ingin digunakan harus di-import terlebih dahulu demgam menggunakan syntax:
#
# `import namaLibrary as abc`
#
# Bagian syntax "as abc" opsional, namun khususnya bagian "abc" biasanya sudah ada best practice penamaan library (Seperti np untuk NumPy, pd untuk Pandas, dsb.) dan akan teman-teman gunakan untuk "memanggil" fungsi (fitur) yang ditawarkan sebuah library.

# %%
# %pip install scikit-learn
# %pip install bayesian-optimization
# Out:
# Requirement already satisfied: scikit-learn in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (1.6.1)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: bayesian-optimization in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.0.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in c:\users\hp\appdata\roaming\python\python312\site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: numpy>=1.25 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bayesian-optimization) (1.26.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bayesian-optimization) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from bayesian-optimization) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GRU, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from bayes_opt import BayesianOptimization

# %% [markdown]
# # **2. Data Loading**

# %%
# 1. Load data dan set index
df = pd.read_csv('data_merge.csv')
df['date'] = pd.to_datetime(df['Unnamed: 0'])  # Konversi ke datetime
df = df.set_index('date')  # Set sebagai index
df = df.drop('Unnamed: 0', axis=1)  # Hapus kolom asli

# 2. Sort berdasarkan tanggal
df = df.sort_index()

# 3. Cek hasil
print("Data shape:", df.shape)
print("\nFirst few rows:")
print(df.head())

# 4. Cek info data
print("\nData info:")
print(df.info())

# 5. Visualisasi data
plt.figure(figsize=(12, 6))
df['Jumlah_Kasus_TB'].plot()
plt.title('TB Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.grid(True)
plt.show()

# 6. Cek missing values
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Data shape: (1827, 11)
#
# First few rows:
#                    pm2p5          pm10      tcco         tcno2     gtco3  \
# date
# 2020-01-01  1.117303e-08  1.581350e-08  0.000842  8.595702e-07  0.005310
# 2020-01-02  1.020425e-08  1.448988e-08  0.000846  8.332591e-07  0.005313
# 2020-01-03  1.245803e-08  1.731650e-08  0.000844  8.671530e-07  0.005310
# 2020-01-04  1.430548e-08  1.921870e-08  0.000843  8.642510e-07  0.005325
# 2020-01-05  1.466172e-08  1.937695e-08  0.000832  8.476774e-07  0.005348
#
#                    tcso2  Day  Jumlah_Kasus_TB    Bulan  Tahun  Bulan_Angka
# date
# 2020-01-01  4.195158e-07    1             1414  2020-01   2020            1
# 2020-01-02  4.175671e-07    2             1414  2020-01   2020            1
# 2020-01-03  4.265508e-07    3             1414  2020-01   2020            1
# 2020-01-04  4.496984e-07    4             1414  2020-01   2020            1
# 2020-01-05  4.431366e-07    5             1414  2020-01   2020            1
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1827 entries, 2020-01-01 to 2024-12-31
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pm2p5            1827 non-null   float64
#  1   pm10             1827 non-null   float64
#  2   tcco             1827 non-null   float64
#  3   tcno2            1827 non-null   float64
#  4   gtco3            1827 non-null   float64
#  5   tcso2            1827 non-null   float64
#  6   Day              1827 non-null   int64
#  7   Jumlah_Kasus_TB  1827 non-null   int64
#  8   Bulan            1827 non-null   object
#  9   Tahun            1827 non-null   int64
#  10  Bulan_Angka      1827 non-null   int64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 171.3+ KB
# None
# Missing values:
# pm2p5              0
# pm10               0
# tcco               0
# tcno2              0
# gtco3              0
# tcso2              0
# Day                0
# Jumlah_Kasus_TB    0
# Bulan              0
# Tahun              0
# Bulan_Angka        0
# dtype: int64

# %% [markdown]
# # **3. Data Preprocessing**

# %%
# Data Preprocessing
print("\nPreprData Preprocessingocessing data...")

# Create time features
df['month_sin'] = np.sin(2 * np.pi * df['Bulan_Angka']/12)
df['month_cos'] = np.cos(2 * np.pi * df['Bulan_Angka']/12)
df['day_of_week'] = df.index.to_series().dt.dayofweek
df['day_of_week_sin'] = np.sin(2 * np.pi * df['day_of_week']/7)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['day_of_week']/7)
# Out:
# PreprData Preprocessingocessing data...

# %% [markdown]
# ## **Create lag features**

# %%
# Create lag features
target_col = 'Jumlah_Kasus_TB'
lag_list = [1, 7, 14, 30]
for lag in lag_list:
    df[f'{target_col}_lag_{lag}'] = df[target_col].shift(lag)

# Drop rows with NaN values
df = df.dropna()

# %% [markdown]
# # **4. Prepare Features and Target**

# %% [markdown]
# ## **Define feature columns (excluding date and target)**

# %%
# Fitur input
feature_cols = [
    'pm2p5', 'pm10', 'tcco', 'tcno2', 'gtco3', 'tcso2',
    'Jumlah_Kasus_TB_lag_1', 'Jumlah_Kasus_TB_lag_7', 'Jumlah_Kasus_TB_lag_14', 'Jumlah_Kasus_TB_lag_30'
]
X = df[feature_cols].values
y = df['Jumlah_Kasus_TB'].values

# %% [markdown]
# ## **Normalize Data**

# %%
print("\nNormalizing data...")
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()
# Out:
# Normalizing data...

# %% [markdown]
# ## **Create Sequences**

# %%
print("\nCreating sequences...")
time_steps = 14
X_seq, y_seq = [], []
for i in range(len(X_scaled) - time_steps):
    X_seq.append(X_scaled[i:i + time_steps])
    y_seq.append(y_scaled[i + time_steps])

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)
# Out:
# Creating sequences...

# %% [markdown]
# ## **Split Data*

# %%
print("\nSplitting data...")
train_size = int(0.7 * len(X_seq))

X_train = X_seq[:train_size]
y_train = y_seq[:train_size]
X_test = X_seq[train_size:]
y_test = y_seq[train_size:]

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Splitting data...
# Training data shape: (1248, 14, 10)
# Testing data shape: (535, 14, 10)

# %% [markdown]
# # **Define Model Architecture**

# %%
def build_model(input_shape, gru_units=64, dropout_rate=0.2, 
                filters_1=64, filters_2=128, kernel_size=3):
    model = Sequential()
    
    # First CNN block
    model.add(Input(shape=input_shape))
    model.add(Conv1D(filters=filters_1, kernel_size=kernel_size,
                    strides=1, padding='causal', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    
    # Second CNN block
    model.add(Conv1D(filters=filters_2, kernel_size=kernel_size,
                    padding='causal', activation='relu', dilation_rate=2))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    
    # GRU layers
    model.add(GRU(units=gru_units, return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(GRU(units=gru_units))
    model.add(Dropout(dropout_rate))
    
    # Output layers
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout_rate/2))
    model.add(Dense(1))
    
    return model

# %% [markdown]
# ## **Bayesian Optimization**

# %%
print("\nPerforming Bayesian Optimization...")

def objective_function(gru_units, dropout_rate, learning_rate, batch_size, 
                      filters_1, filters_2, kernel_size):
    # Convert parameters to appropriate types
    gru_units = int(gru_units)
    batch_size = int(batch_size)
    filters_1 = int(filters_1)
    filters_2 = int(filters_2)
    kernel_size = int(kernel_size)
    
    # Create and compile model
    model = build_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        gru_units=gru_units,
        dropout_rate=dropout_rate,
        filters_1=filters_1,
        filters_2=filters_2,
        kernel_size=kernel_size
    )
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    
    # Train model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        batch_size=batch_size,
        epochs=50,
        verbose=0
    )
    
    return -min(history.history['val_loss'])
# Out:
# Performing Bayesian Optimization...

# %% [markdown]
# ## **Define parameter bounds**

# %%
pbounds = {
    'gru_units': (32, 256),
    'dropout_rate': (0.1, 0.5),
    'learning_rate': (0.0001, 0.01),
    'batch_size': (16, 128),
    'filters_1': (32, 128),
    'filters_2': (64, 256),
    'kernel_size': (2, 5)
}

# %% [markdown]
# ## **Run Bayesian Optimization**

# %%
from bayes_opt import BayesianOptimization

# Buat optimizer
optimizer = BayesianOptimization(
    f=objective_function,
    pbounds=pbounds,
    random_state=1
)

# Jalankan optimisasi
optimizer.maximize(
    init_points=5,  # Number of initial random points
    n_iter=20      # Number of optimization iterations
)

# Ambil parameter terbaik
best_params = optimizer.max['params']
print("\nBest hyperparameters:", best_params)
# Out:
# |   iter    |  target   | batch_... | dropou... | filters_1 | filters_2 | gru_units | kernel... | learni... |
# -------------------------------------------------------------------------------------------------------------
# | 1         | -0.08638  | 62.71     | 0.3881    | 32.01     | 122.0     | 64.87     | 2.277     | 0.001944  |
# | 2         | -0.06192  | 54.7      | 0.2587    | 83.73     | 144.5     | 185.5     | 2.613     | 0.008793  |
# | 3         | -0.08857  | 19.07     | 0.3682    | 72.06     | 171.3     | 63.45     | 2.594     | 0.008027  |
# | 4         | -0.07532  | 124.4     | 0.2254    | 98.46     | 232.3     | 232.4     | 2.255     | 0.0004866 |
# | 5         | -0.05412  | 35.02     | 0.4513    | 41.44     | 144.9     | 246.6     | 3.599     | 0.00695   |
# | 6         | -0.04944  | 21.3      | 0.4322    | 109.2     | 67.19     | 253.5     | 4.1       | 0.001078  |
# | 7         | -0.08445  | 115.6     | 0.1227    | 37.23     | 74.65     | 251.6     | 4.327     | 0.008671  |
# | 8         | -0.0781   | 18.82     | 0.1291    | 122.2     | 144.2     | 247.5     | 4.965     | 0.007389  |
# | 9         | -0.09316  | 25.94     | 0.2308    | 77.97     | 81.52     | 230.4     | 3.785     | 0.00079   |
# | 10        | -0.08785  | 56.94     | 0.1133    | 86.72     | 142.6     | 186.9     | 4.843     | 0.005559  |
# | 11        | -0.05128  | 96.26     | 0.3606    | 42.04     | 80.72     | 178.8     | 4.494     | 0.002098  |
# | 12        | -0.05795  | 119.6     | 0.4353    | 32.73     | 235.7     | 33.2      | 3.526     | 0.004501  |
# | 13        | -0.07509  | 126.0     | 0.1792    | 121.2     | 143.7     | 122.6     | 2.048     | 0.007828  |
# | 14        | -0.08584  | 86.43     | 0.4315    | 91.81     | 127.4     | 97.88     | 2.273     | 0.0002355 |
# | 15        | -0.06104  | 68.12     | 0.1943    | 50.43     | 82.58     | 239.8     | 3.287     | 0.006004  |
# | 16        | -0.103    | 108.5     | 0.411     | 100.9     | 208.2     | 224.4     | 2.02      | 0.0071    |
# | 17        | -0.05939  | 108.7     | 0.3366    | 90.91     | 169.5     | 166.0     | 3.915     | 0.003519  |
# | 18        | -0.03666  | 31.34     | 0.4972    | 60.87     | 194.0     | 60.37     | 4.165     | 0.0008791 |
# | 19        | -0.07797  | 83.2      | 0.2033    | 113.6     | 166.1     | 107.5     | 4.613     | 0.006112  |
# | 20        | -0.05993  | 18.13     | 0.4451    | 73.02     | 101.6     | 184.6     | 3.242     | 0.003864  |
# | 21        | -0.07616  | 42.56     | 0.2904    | 59.09     | 246.0     | 234.0     | 4.599     | 0.008161  |
# | 22        | -0.04595  | 66.84     | 0.4484    | 74.92     | 80.35     | 47.35     | 4.185     | 0.007117  |
# | 23        | -0.07242  | 45.37     | 0.2677    | 63.63     | 92.71     | 243.3     | 2.252     | 0.005343  |
# | 24        | -0.06557  | 79.44     | 0.3323    | 80.63     | 184.1     | 34.99     | 2.782     | 0.006244  |
# | 25        | -0.07879  | 124.0     | 0.137     | 96.23     | 221.9     | 181.8     | 3.621     | 0.008691  |
# =============================================================================================================
#
# Best hyperparameters: {'batch_size': 31.344778640005565, 'dropout_rate': 0.4972391544862097, 'filters_1': 60.868414615914304, 'filters_2': 193.95302256787406, 'gru_units': 60.37342231864926, 'kernel_size': 4.164691808571245, 'learning_rate': 0.0008791058815453526}

# %% [markdown]
# # **Train Final Model**

# %%
print("\nTraining final model...")

# Build final model with best parameters
final_model = build_model(
    input_shape=(X_train.shape[1], X_train.shape[2]),
    gru_units=int(best_params['gru_units']),
    dropout_rate=best_params['dropout_rate'],
    filters_1=int(best_params['filters_1']),
    filters_2=int(best_params['filters_2']),
    kernel_size=int(best_params['kernel_size'])
)

# Compile model
optimizer = tf.keras.optimizers.Adam(learning_rate=best_params['learning_rate'])
final_model.compile(
    optimizer=optimizer,
    loss='mean_squared_error',
    metrics=['mae', tf.keras.metrics.RootMeanSquaredError(name='rmse')]
)

# Define callbacks
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, verbose=1, restore_best_weights=True),
    ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
]

# Train model
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=int(best_params['batch_size']),
    epochs=100,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Training final model...
# Epoch 1/100
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5645 - mae: 0.5985 - rmse: 0.7436
# Epoch 1: val_loss improved from inf to 0.27973, saving model to best_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - loss: 0.5538 - mae: 0.5921 - rmse: 0.7364 - val_loss: 0.2797 - val_mae: 0.4771 - val_rmse: 0.5289 - learning_rate: 8.7911e-04
# Epoch 2/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2907 - mae: 0.4372 - rmse: 0.5390
# Epoch 2: val_loss improved from 0.27973 to 0.17393, saving model to best_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2884 - mae: 0.4347 - rmse: 0.5369 - val_loss: 0.1739 - val_mae: 0.3577 - val_rmse: 0.4171 - learning_rate: 8.7911e-04
# Epoch 3/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2103 - mae: 0.3623 - rmse: 0.4585
# Epoch 3: val_loss improved from 0.17393 to 0.11050, saving model to best_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2104 - mae: 0.3622 - rmse: 0.4586 - val_loss: 0.1105 - val_mae: 0.2816 - val_rmse: 0.3324 - learning_rate: 8.7911e-04
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1796 - mae: 0.3402 - rmse: 0.4233
# Epoch 4: val_loss improved from 0.11050 to 0.08859, saving model to best_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1796 - mae: 0.3401 - rmse: 0.4233 - val_loss: 0.0886 - val_mae: 0.2392 - val_rmse: 0.2976 - learning_rate: 8.7911e-04
# Epoch 5/100
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1783 - mae: 0.3304 - rmse: 0.4222
# Epoch 5: val_loss did not improve from 0.08859
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1781 - mae: 0.3301 - rmse: 0.4219 - val_loss: 0.1079 - val_mae: 0.2544 - val_rmse: 0.3284 - learning_rate: 8.7911e-04
# Epoch 6/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1616 - mae: 0.3197 - rmse: 0.4019
# Epoch 6: val_loss improved from 0.08859 to 0.08042, saving model to best_model.keras
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1615 - mae: 0.3194 - rmse: 0.4018 - val_loss: 0.0804 - val_mae: 0.2051 - val_rmse: 0.2836 - learning_rate: 8.7911e-04
# Epoch 7/100
# 37/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1450 - mae: 0.2977 - rmse: 0.3807
# Epoch 7: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1452 - mae: 0.2981 - rmse: 0.3810 - val_loss: 0.0982 - val_mae: 0.2370 - val_rmse: 0.3133 - learning_rate: 8.7911e-04
# Epoch 8/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1492 - mae: 0.3043 - rmse: 0.3863
# Epoch 8: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1478 - mae: 0.3025 - rmse: 0.3843 - val_loss: 0.1243 - val_mae: 0.2567 - val_rmse: 0.3526 - learning_rate: 8.7911e-04
# Epoch 9/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1194 - mae: 0.2722 - rmse: 0.3452
# Epoch 9: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1196 - mae: 0.2719 - rmse: 0.3454 - val_loss: 0.0817 - val_mae: 0.2217 - val_rmse: 0.2859 - learning_rate: 8.7911e-04
# Epoch 10/100
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1308 - mae: 0.2811 - rmse: 0.3615
# Epoch 10: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1305 - mae: 0.2808 - rmse: 0.3612 - val_loss: 0.0931 - val_mae: 0.2425 - val_rmse: 0.3051 - learning_rate: 8.7911e-04
# Epoch 11/100
# 37/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1154 - mae: 0.2676 - rmse: 0.3395
# Epoch 11: val_loss did not improve from 0.08042
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0004395529394969344.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1146 - mae: 0.2667 - rmse: 0.3384 - val_loss: 0.1122 - val_mae: 0.2756 - val_rmse: 0.3350 - learning_rate: 8.7911e-04
# Epoch 12/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1077 - mae: 0.2521 - rmse: 0.3280
# Epoch 12: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1090 - mae: 0.2535 - rmse: 0.3300 - val_loss: 0.0842 - val_mae: 0.2183 - val_rmse: 0.2902 - learning_rate: 4.3955e-04
# Epoch 13/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1005 - mae: 0.2477 - rmse: 0.3169
# Epoch 13: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1013 - mae: 0.2485 - rmse: 0.3182 - val_loss: 0.1243 - val_mae: 0.2953 - val_rmse: 0.3525 - learning_rate: 4.3955e-04
# Epoch 14/100
# 35/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1022 - mae: 0.2424 - rmse: 0.3196
# Epoch 14: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1020 - mae: 0.2426 - rmse: 0.3193 - val_loss: 0.0961 - val_mae: 0.2469 - val_rmse: 0.3099 - learning_rate: 4.3955e-04
# Epoch 15/100
# 35/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0908 - mae: 0.2329 - rmse: 0.3012
# Epoch 15: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0917 - mae: 0.2341 - rmse: 0.3027 - val_loss: 0.0970 - val_mae: 0.2487 - val_rmse: 0.3115 - learning_rate: 4.3955e-04
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0905 - mae: 0.2349 - rmse: 0.3006
# Epoch 16: val_loss did not improve from 0.08042
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002197764697484672.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0906 - mae: 0.2349 - rmse: 0.3008 - val_loss: 0.1163 - val_mae: 0.2832 - val_rmse: 0.3411 - learning_rate: 4.3955e-04
# Epoch 17/100
# 35/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0809 - mae: 0.2200 - rmse: 0.2842
# Epoch 17: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0822 - mae: 0.2219 - rmse: 0.2865 - val_loss: 0.0907 - val_mae: 0.2406 - val_rmse: 0.3011 - learning_rate: 2.1978e-04
# Epoch 18/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0995 - mae: 0.2463 - rmse: 0.3153
# Epoch 18: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0995 - mae: 0.2457 - rmse: 0.3152 - val_loss: 0.0983 - val_mae: 0.2556 - val_rmse: 0.3136 - learning_rate: 2.1978e-04
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0834 - mae: 0.2266 - rmse: 0.2885
# Epoch 19: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0834 - mae: 0.2267 - rmse: 0.2886 - val_loss: 0.0978 - val_mae: 0.2548 - val_rmse: 0.3128 - learning_rate: 2.1978e-04
# Epoch 20/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0869 - mae: 0.2302 - rmse: 0.2947
# Epoch 20: val_loss did not improve from 0.08042
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0866 - mae: 0.2293 - rmse: 0.2942 - val_loss: 0.0870 - val_mae: 0.2431 - val_rmse: 0.2949 - learning_rate: 2.1978e-04
# Epoch 21/100
# 36/41 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0952 - mae: 0.2397 - rmse: 0.3082
# Epoch 21: val_loss did not improve from 0.08042
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001098882348742336.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0943 - mae: 0.2385 - rmse: 0.3067 - val_loss: 0.1179 - val_mae: 0.2885 - val_rmse: 0.3433 - learning_rate: 2.1978e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %% [markdown]
# # **Evaluate Final Model**

# %%
# 10. Evaluate Model
print("\nEvaluating model...")

# Make predictions
y_pred = final_model.predict(X_test)

# Inverse transform predictions
y_test_orig = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()
y_pred_orig = scaler_y.inverse_transform(y_pred).flatten()

# Calculate metrics
mse = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)

print("\nModel Evaluation Metrics:")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R²: {r2:.4f}")

# 11. Visualize Results
plt.figure(figsize=(12, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred_orig, label='Predicted')
plt.title('TB Cases: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Number of TB Cases')
plt.legend()
plt.grid(True)
plt.show()

# Plot prediction error
plt.figure(figsize=(12, 6))
plt.plot(y_test_orig - y_pred_orig)
plt.title('Prediction Error')
plt.xlabel('Time')
plt.ylabel('Error')
plt.axhline(y=0, color='r', linestyle='-')
plt.grid(True)
plt.show()

# Plot training history
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Evaluating model...
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#
# Model Evaluation Metrics:
# MSE: 36091.3468
# RMSE: 189.9772
# MAE: 137.4216
# R²: 0.1566
